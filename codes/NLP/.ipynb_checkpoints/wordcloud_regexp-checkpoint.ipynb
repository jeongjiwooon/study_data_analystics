# %%
# !pip install wordcloud
# Out:
# Requirement already satisfied: wordcloud in c:\users\5-22\anaconda3\lib\site-packages (1.9.2)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\5-22\anaconda3\lib\site-packages (from wordcloud) (1.24.3)
# Requirement already satisfied: pillow in c:\users\5-22\anaconda3\lib\site-packages (from wordcloud) (9.4.0)
# Requirement already satisfied: matplotlib in c:\users\5-22\anaconda3\lib\site-packages (from wordcloud) (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\5-22\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\5-22\anaconda3\lib\site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\5-22\anaconda3\lib\site-packages (from matplotlib->wordcloud) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\5-22\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\5-22\anaconda3\lib\site-packages (from matplotlib->wordcloud) (23.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\5-22\anaconda3\lib\site-packages (from matplotlib->wordcloud) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\5-22\anaconda3\lib\site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\5-22\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)

# %%
from wordcloud import WordCloud

# %%
# 한글 문장 리스트
sentences = [
    "이 영화는 정말로 감동적이었습니다. 배우들의 연기력과 스토리텔링이 훌륭하며, 마지막 장면은 정말로 눈물을 자아내었습니다.",
    "시간 가는 줄 모르고 봤네요. 몰입도가 너무 높아서 이야기에 완전히 흡수되었습니다. 추천합니다!",
    "배경 음악부터 촬영 기법까지 모든 면에서 완벽한 영화입니다. 저는 이런 작품을 기다렸던 것 같아요.",
    "스릴 넘치는 액션과 긴장감 있는 플롯으로 지루할 틈 없이 재미있게 볼 수 있었습니다. 꼭 보세요!",
    "캐릭터들의 감정 변화와 내면 성장을 그린 이야기가 인상 깊었습니다. 여운이 오래 남았어요.",
    "대단한 시나리오와 함께 최고의 캐스팅! 배우들의 연기력은 정말 대단하다고 생각합니다.",
    "영상미와 비주얼 효과가 화려하고 아름다웠습니다. 시각적으로도 매우 만족스러웠어요.",
    "천재적인 감독의 솜씨가 돋보이는 작품입니다. 전체적인 분위기와 스토리 전개가 완벽하게 어우러져 있습니다.",
    "영화 속 캐릭터들의 대사와 유머 감각이 정말 좋았습니다. 웃음 가득한 시간을 보낼 수 있었습니다.",
    "심오한 주제를 다룬 영화로서 생각할 거리를 많이 주었습니다. 여운이 오래 남을 것 같아요."
]

# %% [markdown]
# ## 자연어 처리 위한 단어 생성

# %%
# "맛있는 음식을 먹으러 갈까요?" -> 4개
# "여행 계획을 세우고 있는데 어디로 갈까요?" -> 6개
# 10개이지만 동일한 단어는 겹칠 수 있다.
text=''.join(sentences)
text
# Out:
# '이 영화는 정말로 감동적이었습니다. 배우들의 연기력과 스토리텔링이 훌륭하며, 마지막 장면은 정말로 눈물을 자아내었습니다.시간 가는 줄 모르고 봤네요. 몰입도가 너무 높아서 이야기에 완전히 흡수되었습니다. 추천합니다!배경 음악부터 촬영 기법까지 모든 면에서 완벽한 영화입니다. 저는 이런 작품을 기다렸던 것 같아요.스릴 넘치는 액션과 긴장감 있는 플롯으로 지루할 틈 없이 재미있게 볼 수 있었습니다. 꼭 보세요!캐릭터들의 감정 변화와 내면 성장을 그린 이야기가 인상 깊었습니다. 여운이 오래 남았어요.대단한 시나리오와 함께 최고의 캐스팅! 배우들의 연기력은 정말 대단하다고 생각합니다.영상미와 비주얼 효과가 화려하고 아름다웠습니다. 시각적으로도 매우 만족스러웠어요.천재적인 감독의 솜씨가 돋보이는 작품입니다. 전체적인 분위기와 스토리 전개가 완벽하게 어우러져 있습니다.영화 속 캐릭터들의 대사와 유머 감각이 정말 좋았습니다. 웃음 가득한 시간을 보낼 수 있었습니다.심오한 주제를 다룬 영화로서 생각할 거리를 많이 주었습니다. 여운이 오래 남을 것 같아요.'

# %%
## 조사 빼기
# 는, 이, 은, 를, 한, 가, ...
import re
pattern = r'[는은이가을를만의과에]'
text_regex = re.sub(pattern=pattern, repl='', string=text) # params: 변경대상, 대상 대체, 어떤것을
text_regex
# Out:
# ' 영화 정말로 감동적었습니다. 배우들 연기력 스토리텔링 훌륭하며, 마지막 장면 정말로 눈물 자아내었습니다.시간  줄 모르고 봤네요. 몰입도 너무 높아서 야기 완전히 흡수되었습니다. 추천합니다!배경 음악부터 촬영 기법까지 모든 면서 완벽한 영화입니다. 저 런 작품 기다렸던 것 같아요.스릴 넘치 액션 긴장감 있 플롯으로 지루할 틈 없 재미있게 볼 수 있었습니다. 꼭 보세요!캐릭터들 감정 변화와 내면 성장 그린 야기 인상 깊었습니다. 여운 오래 남았어요.대단한 시나리오와 함께 최고 캐스팅! 배우들 연기력 정말 대단하다고 생각합니다.영상미와 비주얼 효 화려하고 아름다웠습니다. 시각적으로도 매우 족스러웠어요.천재적인 감독 솜씨 돋보 작품입니다. 전체적인 분위기와 스토리 전개 완벽하게 어우러져 있습니다.영화 속 캐릭터들 대사와 유머 감각 정말 좋았습니다. 웃음 득한 시간 보낼 수 있었습니다.심오한 주제 다룬 영화로서 생각할 거리 많 주었습니다. 여운 오래 남 것 같아요.'

# %%
text_split = text.split()
text_split
# Out:
# ['이',
#  '영화는',
#  '정말로',
#  '감동적이었습니다.',
#  '배우들의',
#  '연기력과',
#  '스토리텔링이',
#  '훌륭하며,',
#  '마지막',
#  '장면은',
#  '정말로',
#  '눈물을',
#  '자아내었습니다.시간',
#  '가는',
#  '줄',
#  '모르고',
#  '봤네요.',
#  '몰입도가',
#  '너무',
#  '높아서',
#  '이야기에',
#  '완전히',
#  '흡수되었습니다.',
#  '추천합니다!배경',
#  '음악부터',
#  '촬영',
#  '기법까지',
#  '모든',
#  '면에서',
#  '완벽한',
#  '영화입니다.',
#  '저는',
#  '이런',
#  '작품을',
#  '기다렸던',
#  '것',
#  '같아요.스릴',
#  '넘치는',
#  '액션과',
#  '긴장감',
#  '있는',
#  '플롯으로',
#  '지루할',
#  '틈',
#  '없이',
#  '재미있게',
#  '볼',
#  '수',
#  '있었습니다.',
#  '꼭',
#  '보세요!캐릭터들의',
#  '감정',
#  '변화와',
#  '내면',
#  '성장을',
#  '그린',
#  '이야기가',
#  '인상',
#  '깊었습니다.',
#  '여운이',
#  '오래',
#  '남았어요.대단한',
#  '시나리오와',
#  '함께',
#  '최고의',
#  '캐스팅!',
#  '배우들의',
#  '연기력은',
#  '정말',
#  '대단하다고',
#  '생각합니다.영상미와',
#  '비주얼',
#  '효과가',
#  '화려하고',
#  '아름다웠습니다.',
#  '시각적으로도',
#  '매우',
#  '만족스러웠어요.천재적인',
#  '감독의',
#  '솜씨가',
#  '돋보이는',
#  '작품입니다.',
#  '전체적인',
#  '분위기와',
#  '스토리',
#  '전개가',
#  '완벽하게',
#  '어우러져',
#  '있습니다.영화',
#  '속',
#  '캐릭터들의',
#  '대사와',
#  '유머',
#  '감각이',
#  '정말',
#  '좋았습니다.',
#  '웃음',
#  '가득한',
#  '시간을',
#  '보낼',
#  '수',
#  '있었습니다.심오한',
#  '주제를',
#  '다룬',
#  '영화로서',
#  '생각할',
#  '거리를',
#  '많이',
#  '주었습니다.',
#  '여운이',
#  '오래',
#  '남을',
#  '것',
#  '같아요.']

# %%
from collections import Counter
Counter(text_regex.split()) # list를 count
# Out:
# Counter({'영화': 1,
#          '정말로': 2,
#          '감동적었습니다.': 1,
#          '배우들': 2,
#          '연기력': 2,
#          '스토리텔링': 1,
#          '훌륭하며,': 1,
#          '마지막': 1,
#          '장면': 1,
#          '눈물': 1,
#          '자아내었습니다.시간': 1,
#          '줄': 1,
#          '모르고': 1,
#          '봤네요.': 1,
#          '몰입도': 1,
#          '너무': 1,
#          '높아서': 1,
#          '야기': 2,
#          '완전히': 1,
#          '흡수되었습니다.': 1,
#          '추천합니다!배경': 1,
#          '음악부터': 1,
#          '촬영': 1,
#          '기법까지': 1,
#          '모든': 1,
#          '면서': 1,
#          '완벽한': 1,
#          '영화입니다.': 1,
#          '저': 1,
#          '런': 1,
#          '작품': 1,
#          '기다렸던': 1,
#          '것': 2,
#          '같아요.스릴': 1,
#          '넘치': 1,
#          '액션': 1,
#          '긴장감': 1,
#          '있': 1,
#          '플롯으로': 1,
#          '지루할': 1,
#          '틈': 1,
#          '없': 1,
#          '재미있게': 1,
#          '볼': 1,
#          '수': 2,
#          '있었습니다.': 1,
#          '꼭': 1,
#          '보세요!캐릭터들': 1,
#          '감정': 1,
#          '변화와': 1,
#          '내면': 1,
#          '성장': 1,
#          '그린': 1,
#          '인상': 1,
#          '깊었습니다.': 1,
#          '여운': 2,
#          '오래': 2,
#          '남았어요.대단한': 1,
#          '시나리오와': 1,
#          '함께': 1,
#          '최고': 1,
#          '캐스팅!': 1,
#          '정말': 2,
#          '대단하다고': 1,
#          '생각합니다.영상미와': 1,
#          '비주얼': 1,
#          '효': 1,
#          '화려하고': 1,
#          '아름다웠습니다.': 1,
#          '시각적으로도': 1,
#          '매우': 1,
#          '족스러웠어요.천재적인': 1,
#          '감독': 1,
#          '솜씨': 1,
#          '돋보': 1,
#          '작품입니다.': 1,
#          '전체적인': 1,
#          '분위기와': 1,
#          '스토리': 1,
#          '전개': 1,
#          '완벽하게': 1,
#          '어우러져': 1,
#          '있습니다.영화': 1,
#          '속': 1,
#          '캐릭터들': 1,
#          '대사와': 1,
#          '유머': 1,
#          '감각': 1,
#          '좋았습니다.': 1,
#          '웃음': 1,
#          '득한': 1,
#          '시간': 1,
#          '보낼': 1,
#          '있었습니다.심오한': 1,
#          '주제': 1,
#          '다룬': 1,
#          '영화로서': 1,
#          '생각할': 1,
#          '거리': 1,
#          '많': 1,
#          '주었습니다.': 1,
#          '남': 1,
#          '같아요.': 1})

# %%
# 한글 폰트 경로 설정 (Windows 환경에 맞게 경로 수정)
font_path = 'C:/Windows/Fonts/malgun.ttf'

wordCloud = WordCloud(font_path=font_path, background_color='white')
wordCloud.generate_from_text(text)

# %%
wordCloud.words_
# Out:
# {'정말로': 1.0,
#  '배우들의': 1.0,
#  '것': 1.0,
#  '같아요': 1.0,
#  '수': 1.0,
#  '있었습니다': 1.0,
#  '캐릭터들의': 1.0,
#  '여운이': 1.0,
#  '오래': 1.0,
#  '정말': 1.0,
#  '이': 0.5,
#  '영화는': 0.5,
#  '감동적이었습니다': 0.5,
#  '연기력과': 0.5,
#  '스토리텔링이': 0.5,
#  '훌륭하며': 0.5,
#  '마지막': 0.5,
#  '장면은': 0.5,
#  '눈물을': 0.5,
#  '자아내었습니다': 0.5,
#  '시간': 0.5,
#  '가는': 0.5,
#  '줄': 0.5,
#  '모르고': 0.5,
#  '봤네요': 0.5,
#  '몰입도가': 0.5,
#  '너무': 0.5,
#  '높아서': 0.5,
#  '이야기에': 0.5,
#  '완전히': 0.5,
#  '흡수되었습니다': 0.5,
#  '추천합니다': 0.5,
#  '배경': 0.5,
#  '음악부터': 0.5,
#  '촬영': 0.5,
#  '기법까지': 0.5,
#  '모든': 0.5,
#  '면에서': 0.5,
#  '완벽한': 0.5,
#  '영화입니다': 0.5,
#  '저는': 0.5,
#  '이런': 0.5,
#  '작품을': 0.5,
#  '기다렸던': 0.5,
#  '스릴': 0.5,
#  '넘치는': 0.5,
#  '액션과': 0.5,
#  '긴장감': 0.5,
#  '있는': 0.5,
#  '플롯으로': 0.5,
#  '지루할': 0.5,
#  '틈': 0.5,
#  '없이': 0.5,
#  '재미있게': 0.5,
#  '볼': 0.5,
#  '꼭': 0.5,
#  '보세요': 0.5,
#  '감정': 0.5,
#  '변화와': 0.5,
#  '내면': 0.5,
#  '성장을': 0.5,
#  '그린': 0.5,
#  '이야기가': 0.5,
#  '인상': 0.5,
#  '깊었습니다': 0.5,
#  '남았어요': 0.5,
#  '대단한': 0.5,
#  '시나리오와': 0.5,
#  '함께': 0.5,
#  '최고의': 0.5,
#  '캐스팅': 0.5,
#  '연기력은': 0.5,
#  '대단하다고': 0.5,
#  '생각합니다': 0.5,
#  '영상미와': 0.5,
#  '비주얼': 0.5,
#  '효과가': 0.5,
#  '화려하고': 0.5,
#  '아름다웠습니다': 0.5,
#  '시각적으로도': 0.5,
#  '매우': 0.5,
#  '만족스러웠어요': 0.5,
#  '천재적인': 0.5,
#  '감독의': 0.5,
#  '솜씨가': 0.5,
#  '돋보이는': 0.5,
#  '작품입니다': 0.5,
#  '전체적인': 0.5,
#  '분위기와': 0.5,
#  '스토리': 0.5,
#  '전개가': 0.5,
#  '완벽하게': 0.5,
#  '어우러져': 0.5,
#  '있습니다': 0.5,
#  '영화': 0.5,
#  '속': 0.5,
#  '대사와': 0.5,
#  '유머': 0.5,
#  '감각이': 0.5,
#  '좋았습니다': 0.5,
#  '웃음': 0.5,
#  '가득한': 0.5,
#  '시간을': 0.5,
#  '보낼': 0.5,
#  '심오한': 0.5,
#  '주제를': 0.5,
#  '다룬': 0.5,
#  '영화로서': 0.5,
#  '생각할': 0.5,
#  '거리를': 0.5,
#  '많이': 0.5,
#  '주었습니다': 0.5,
#  '남을': 0.5}

# %%
import matplotlib.pyplot as plt
plt.imshow(wordCloud)
plt.axis('off')
plt.show()
