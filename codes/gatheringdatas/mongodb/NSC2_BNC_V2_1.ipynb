# %%
import pymongo as mg

# %%
client = mg.MongoClient(host='mongodb://localhost:27017/')

# %%
client
# Out:
# MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True)

# %%
client['NSC2_BNC_V2_1']
# Out:
# Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'NSC2_BNC_V2_1')

# %%
database = client['NSC2_BNC_V2_1']

# %%
database['NSC2_BNC_V2_1']
# Out:
# Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'NSC2_BNC_V2_1'), 'NSC2_BNC_V2_1')

# %%
collection = database['NSC2_BNC_V2_1']
collection
# Out:
# Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'NSC2_BNC_V2_1'), 'NSC2_BNC_V2_1')

# %%
cursor = collection.find({})
cursor

# %%
list_BV21 = list(cursor)
list_BV21
# Out:
# [{'_id': ObjectId('64d310da73a0a24408f0916d'),
#   'STD_YYYY': 2002,
#   'RN_INDI': 1433,
#   'SEX': 1,
#   'SGG': 29140,
#   'GAIBJA_TYPE': 7,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310da73a0a24408f0916e'),
#   'STD_YYYY': 2003,
#   'RN_INDI': 1433,
#   'SEX': 1,
#   'SGG': 29140,
#   'GAIBJA_TYPE': 7,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310da73a0a24408f0916f'),
#   'STD_YYYY': 2004,
#   'RN_INDI': 1433,
#   'SEX': 1,
#   'SGG': 29140,
#   'GAIBJA_TYPE': 7,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310da73a0a24408f09170'),
#   'STD_YYYY': 2005,
#   'RN_INDI': 1433,
#   'SEX': 1,
#   'SGG': 29140,
#   'GAIBJA_TYPE': 7,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310da73a0a24408f09171'),
#   'STD_YYYY': 2006,
#   'RN_INDI': 1433,
#   'SEX': 1,
#   'SGG': 29140,
#   'GAIBJA_TYPE': 7,
#   'SMPL_TYPE_CD': 1},
#  {'_id': ObjectId('64d310da73a0a24408f09172'),
#   'STD_YYYY': 2007,
#   'RN_INDI': 1433,
#   'SEX': 1,
#   'SGG': 29140,
#   'GAIBJA_TYPE': 7,
# ...

# %%
import pandas as pd

# %%
df_BV21 = pd.DataFrame(list_BV21)

# %%
df_BV21
# Out:
#                             _id  STD_YYYY  RN_INDI  SEX    SGG  GAIBJA_TYPE  \
# 0      64d310da73a0a24408f0916d      2002     1433    1  29140            7
# 1      64d310da73a0a24408f0916e      2003     1433    1  29140            7
# 2      64d310da73a0a24408f0916f      2004     1433    1  29140            7
# 3      64d310da73a0a24408f09170      2005     1433    1  29140            7
# 4      64d310da73a0a24408f09171      2006     1433    1  29140            7
# ...                         ...       ...      ...  ...    ...          ...
# 13022  64d310db73a0a24408f0c44b      2012  3000357    2  28237            6
# 13023  64d310db73a0a24408f0c44c      2013  3000357    2  28245            2
# 13024  64d310db73a0a24408f0c44d      2014  3000357    2  28245            2
# 13025  64d310db73a0a24408f0c44e      2015  3000357    2  28245            2
# 13026  64d310db73a0a24408f0c44f      2015  3000758    1  41287            6
#
# ...

# %%
df_BV21.to_csv('./df_BV21.csv')
