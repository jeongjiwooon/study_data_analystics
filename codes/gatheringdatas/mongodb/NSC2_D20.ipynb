# %%
import pymongo as mg

# %%
 client = mg.MongoClient(host='mongodb://localhost:27017/')

# %%
client['NSC2_D20']
# Out:
# Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'NSC2_D20')

# %%
database = client['NSC2_D20']

# %%
database['NSC2_D20']
# Out:
# Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'NSC2_D20'), 'NSC2_D20')

# %%
collection = database['NSC2_D20']

# %%
collection.find({})

# %%
cursor = collection.find({})

# %%
list_D20 = list(cursor)

# %%
import pandas as pd

# %%
pd.DataFrame( list_D20)
# Out:
#                             _id  RN_INDI         RN_KEY  RN_INST  \
# 0      64d310e273a0a24408f0c451   668008  2002030294303   140010
# 1      64d310e273a0a24408f0c452   440063  2002030797621   139680
# 2      64d310e273a0a24408f0c453   850654  2002030372244    15041
# 3      64d310e273a0a24408f0c454   783723  2002010004364   108288
# 4      64d310e273a0a24408f0c455   838106  2002010628708    83960
# ...                         ...      ...            ...      ...
# 12525  64d310e373a0a24408f0f53e   312513  2015060094233   118846
# 12526  64d310e373a0a24408f0f53f   533519  2015042356807     7949
# 12527  64d310e373a0a24408f0f540   423793  2015020324868    47288
# 12528  64d310e373a0a24408f0f541   398604  2015010120760   116017
# 12529  64d310e373a0a24408f0f542   398604  2015020991563   116017
#
#        MDCARE_STRT_DT  FORM_CD  MCARE_SUBJ_CD SICK_SYM1 OFIJ_TYPE  OPRTN_YN  \
# 0            20020325        5             54      K051         0         0
# 1            20020325        5             53      K006         0         9
# 2            20020311        5             53      K006         0         9
# 3            20020121        5             55      K006       NaN         9
# 4            20020105        5             50      K006       NaN         9
# ...               ...      ...            ...       ...       ...       ...
# 12525        20150627        5             55     K0300         0         0
# 12526        20150407        5             50     K0765         0         0
# 12527        20150221        5             55     K0766         0         0
# 12528        20150129        5             51      K081         0         9
# 12529        20150211        5             51      K081         0         0
#
#        ...  MCARE_RSLT_TYPE  EDC_ADD_RT  ED_RC_TOT_AMT  EDC_SBA  \
# 0      ...              5.0        0.15          12480     3500
# 1      ...              5.0        0.15          11970     3500
# 2      ...              5.0        0.15          11970     3500
# 3      ...              5.0        0.15          11970     3500
# 4      ...              5.0        0.15          11970     3500
# ...    ...              ...         ...            ...      ...
# 12525  ...              1.0        0.20          91460    36500
# 12526  ...              1.0        0.15          86030    25800
# 12527  ...              1.0        0.15          80490    23600
# 12528  ...              1.0        0.15         488170   244000
# 12529  ...              1.0        0.15         511600   255800
#
#        EDC_INSUR_BRDN_AMT  STD_YYYY  SICK_SYM2  HSPTZ_PATH_TYPE  \
# 0                    8980      2002        NaN              NaN
# 1                    8470      2002        NaN              NaN
# 2                    8470      2002        NaN              NaN
# 3                    8470      2002        NaN              NaN
# 4                    8470      2002        NaN              NaN
# ...                   ...       ...        ...              ...
# 12525               54960      2015        NaN              NaN
# 12526               60230      2015        NaN              NaN
# 12527               56890      2015        NaN              NaN
# 12528              244170      2015        NaN              NaN
# 12529              255800      2015        NaN              NaN
#
#        SPCF_SYM_TYPE FST_HSPTZ_DT
# 0                NaN          NaN
# 1                NaN          NaN
# 2                NaN          NaN
# 3                NaN          NaN
# 4                NaN          NaN
# ...              ...          ...
# 12525            NaN          NaN
# 12526            NaN          NaN
# 12527            NaN          NaN
# 12528            NaN          NaN
# 12529            NaN          NaN
#
# [12530 rows x 23 columns]

# %%
df_D20 = pd.DataFrame(list_D20)

# %%
df_D20
# Out:
#                             _id  RN_INDI         RN_KEY  RN_INST  \
# 0      64d310e273a0a24408f0c451   668008  2002030294303   140010
# 1      64d310e273a0a24408f0c452   440063  2002030797621   139680
# 2      64d310e273a0a24408f0c453   850654  2002030372244    15041
# 3      64d310e273a0a24408f0c454   783723  2002010004364   108288
# 4      64d310e273a0a24408f0c455   838106  2002010628708    83960
# ...                         ...      ...            ...      ...
# 12525  64d310e373a0a24408f0f53e   312513  2015060094233   118846
# 12526  64d310e373a0a24408f0f53f   533519  2015042356807     7949
# 12527  64d310e373a0a24408f0f540   423793  2015020324868    47288
# 12528  64d310e373a0a24408f0f541   398604  2015010120760   116017
# 12529  64d310e373a0a24408f0f542   398604  2015020991563   116017
#
#        MDCARE_STRT_DT  FORM_CD  MCARE_SUBJ_CD SICK_SYM1 OFIJ_TYPE  OPRTN_YN  \
# 0            20020325        5             54      K051         0         0
# 1            20020325        5             53      K006         0         9
# 2            20020311        5             53      K006         0         9
# 3            20020121        5             55      K006       NaN         9
# 4            20020105        5             50      K006       NaN         9
# ...               ...      ...            ...       ...       ...       ...
# 12525        20150627        5             55     K0300         0         0
# 12526        20150407        5             50     K0765         0         0
# 12527        20150221        5             55     K0766         0         0
# 12528        20150129        5             51      K081         0         9
# 12529        20150211        5             51      K081         0         0
#
#        ...  MCARE_RSLT_TYPE  EDC_ADD_RT  ED_RC_TOT_AMT  EDC_SBA  \
# 0      ...              5.0        0.15          12480     3500
# 1      ...              5.0        0.15          11970     3500
# 2      ...              5.0        0.15          11970     3500
# 3      ...              5.0        0.15          11970     3500
# 4      ...              5.0        0.15          11970     3500
# ...    ...              ...         ...            ...      ...
# 12525  ...              1.0        0.20          91460    36500
# 12526  ...              1.0        0.15          86030    25800
# 12527  ...              1.0        0.15          80490    23600
# 12528  ...              1.0        0.15         488170   244000
# 12529  ...              1.0        0.15         511600   255800
#
#        EDC_INSUR_BRDN_AMT  STD_YYYY  SICK_SYM2  HSPTZ_PATH_TYPE  \
# 0                    8980      2002        NaN              NaN
# 1                    8470      2002        NaN              NaN
# 2                    8470      2002        NaN              NaN
# 3                    8470      2002        NaN              NaN
# 4                    8470      2002        NaN              NaN
# ...                   ...       ...        ...              ...
# 12525               54960      2015        NaN              NaN
# 12526               60230      2015        NaN              NaN
# 12527               56890      2015        NaN              NaN
# 12528              244170      2015        NaN              NaN
# 12529              255800      2015        NaN              NaN
#
#        SPCF_SYM_TYPE FST_HSPTZ_DT
# 0                NaN          NaN
# 1                NaN          NaN
# 2                NaN          NaN
# 3                NaN          NaN
# 4                NaN          NaN
# ...              ...          ...
# 12525            NaN          NaN
# 12526            NaN          NaN
# 12527            NaN          NaN
# 12528            NaN          NaN
# 12529            NaN          NaN
#
# [12530 rows x 23 columns]

# %%
df_D20.to_csv('./df_D20.csv')
