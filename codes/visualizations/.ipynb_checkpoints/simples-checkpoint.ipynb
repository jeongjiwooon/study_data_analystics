# %%
x_value = [0, 1, 2, 3, 4]

# %%
x_value, len(x_value)
# Out:
# ([0, 1, 2, 3, 4], 5)

# %%
y_value = [1, 3, 5, 7, 9]
y_value, len(y_value)
# Out:
# ([1, 3, 5, 7, 9], 5)

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib tk # 그래프를 팝업 띄워서 유동적인 조작 및 그림파일 저장가능
# %matplotlib inline # 내부에서 다시 표현 하는것

# %%
import matplotlib as mpl # 한글을 출력하기 위한 기본적인 설정
mpl.rc('font',family='Malgun Gothic')

# %%
plt.scatter(x=x_value, y=y_value)

# %%
plt.scatter(x=x_value, y=y_value)
plt.title('심플타이틀')
plt.show()
